# %% [markdown]
# # Exploratory Data Analysis
# ### Import all the packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load the dataset

# %%
df = pd.read_csv('train.csv')

# %% [markdown]
# ### check the size of data

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# ### How does the data look like?

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 117          118         0       2  Turpin, Mr. William John Robert    male
# 463          464         0       2     Milling, Mr. Jacob Christian    male
# 32            33         1       3         Glynn, Miss. Mary Agatha  female
# 500          501         0       3                 Calic, Mr. Petar    male
# 806          807         0       1           Andrews, Mr. Thomas Jr    male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 117  29.0      1      0   11668  21.0000   NaN        S
# 463  48.0      0      0  234360  13.0000   NaN        S
# 32    NaN      0      0  335677   7.7500   NaN        Q
# 500  17.0      0      0  315086   8.6625   NaN        S
# 806  39.0      0      0  112050   0.0000   A36        S

# %% [markdown]
# ### #what is the data types of columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### #Are there any missing values

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### How does the data look mathematically

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ### #Are there duplicates values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
#         `

# %% [markdown]
# ## Data Cleaning
# #### Fill missing values

# %%
df['Age'].fillna(df['Age'].median(), inplace=True)
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)
df.drop('Cabin', axis=1, inplace=True)  # too many missing values
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_1436\1271394130.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].median(), inplace=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_1436\1271394130.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)

# %% [markdown]
# #### Convert Categorical Data

# %%
df['Sex'] = df['Sex'].map({'male': 0, 'female': 1})
df = pd.get_dummies(df, columns=['Embarked'], drop_first=True)  # Dummy encoding

# %% [markdown]
# ## Univariate Analysis
# #### Survival

# %%
sns.countplot(x='Survived', data=df)
plt.title("Survival Count")
plt.show()

# %% [markdown]
# #### Age distribution

# %%
sns.histplot(df['Age'], kde=True)
plt.title("Age Distribution")
plt.show()

# %% [markdown]
# ## Bivariate Analysis
# #### Survival by Gender

# %%
sns.countplot(x='Sex', hue='Survived', data=df)
plt.title("Survival by Gender")
plt.show()

# %% [markdown]
# #### Survival by Passenger Class

# %%
sns.countplot(x='Pclass', hue='Survived', data=df)
plt.title("Survival by Class")
plt.show()

# %% [markdown]
# #### Age vs Survival (Boxplot)

# %%
sns.boxplot(x='Survived', y='Age', data=df)
plt.title("Age vs Survival")
plt.show()

# %% [markdown]
# ## Multivariate Analysis
# #### Survival by Gender and Class

# %%
sns.catplot(x="Pclass", hue="Sex", col="Survived",
            data=df, kind="count", height=4, aspect=1)
plt.suptitle("Survival by Class and Gender", y=1.05)
plt.show()

# %% [markdown]
# #### Fare vs Age by Class and Survival

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Age', y='Fare', hue='Survived', style='Pclass', data=df)
plt.title("Fare vs Age by Survival and Class")
plt.show()
